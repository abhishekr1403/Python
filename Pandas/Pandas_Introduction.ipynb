# %% [markdown]
# # Pandas Introduction 1

# %% [markdown]
# **Using normal pythhon code**

# %%
import csv

# %%
def calaculate_rating(data,industry=None):
    ratings = []
    for row in data:
        # print(row)
        if row[3]!= "NULL" and (not industry or row[1] == industry):
            ratings.append(float(row[3]))
    max_ratings = max(ratings)
    min_ratings = min(ratings)
    avg_ratings = sum(ratings)/len(ratings)
    return max_ratings, min_ratings, avg_ratings

    
with open("movies.csv") as f:
    data = list(csv.reader(f))
    header = data[0]
    data = data[1:]

max_ratings, min_ratings, avg_ratings = calaculate_rating(data)
print(f'All Records: Min rating: {min_ratings}, Max rating: {max_ratings}, Avg rating: {round(avg_ratings,2)}')

max_ratings, min_ratings ,avg_ratings = calaculate_rating(data, industry='Bollywood')
print(f'All Bollywood: Min rating: {min_ratings}, Max rating: {max_ratings}, Avg rating: {round(avg_ratings,2)}')

max_ratings, min_ratings ,avg_ratings = calaculate_rating(data, industry='Hollywood')
print(f'All Hollywood: Min rating: {min_ratings}, Max rating: {max_ratings}, Avg rating: {round(avg_ratings,2)}')
# Out:
# All Records: Min rating: 1.9, Max rating: 9.3, Avg rating: 7.92
# All Bollywood: Min rating: 1.9, Max rating: 8.4, Avg rating: 7.66
# All Hollywood: Min rating: 6.8, Max rating: 9.3, Avg rating: 8.13

# %% [markdown]
# **Using Pandas**

# %%
import pandas as pd

# %%
df = pd.read_csv('movies.csv')
df
# Out:
#                                           title   industry  release_year  \
# 0                               Pather Panchali  Bollywood          1955
# 1   Doctor Strange in the Multiverse of Madness  Hollywood          2022
# 2                         Thor: The Dark World   Hollywood          2013
# 3                               Thor: Ragnarok   Hollywood          2017
# 4                       Thor: Love and Thunder   Hollywood          2022
# 5                      The Shawshank Redemption  Hollywood          1994
# 6                                  Interstellar  Hollywood          2014
# 7                      The Pursuit of Happyness  Hollywood          2006
# 8                                     Gladiator  Hollywood          2000
# 9                                       Titanic  Hollywood          1997
# 10                        It's a Wonderful Life  Hollywood          1946
# 11                                       Avatar  Hollywood          2009
# ...

# %%
df.tail(5)
# Out:
#                         title   industry  release_year  imdb_rating  \
# 32                  Shershaah  Bollywood          2021          8.4
# 33           K.G.F: Chapter 2  Bollywood          2022          8.4
# 34  Pushpa: The Rise - Part 1  Bollywood          2021          7.6
# 35                        RRR  Bollywood          2022          8.0
# 36   Baahubali: The Beginning  Bollywood          2015          8.0
#
#                  studio  budget  revenue      unit currency language
# 32   Dharma Productions   500.0    950.0  Millions      INR    Hindi
# 33        Hombale Films     1.0     12.5  Billions      INR  Kannada
# 34  Mythri Movie Makers     2.0      3.6  Billions      INR   Telugu
# 35    DVV Entertainment     5.5     12.0  Billions      INR   Telugu
# 36     Arka Media Works     1.8      6.5  Billions      INR   Telugu

# %%
df.sample(4)
# Out:
#                        title   industry  release_year  imdb_rating  \
# 6               Interstellar  Hollywood          2014          8.6
# 9                    Titanic  Hollywood          1997          7.9
# 5   The Shawshank Redemption  Hollywood          1994          9.3
# 32                 Shershaah  Bollywood          2021          8.4
#
#                        studio  budget  revenue      unit currency language
# 6       Warner Bros. Pictures   165.0    701.8  Millions      USD  English
# 9          Paramount Pictures   200.0   2202.0  Millions      USD  English
# 5   Castle Rock Entertainment    25.0     73.3  Millions      USD  English
# 32         Dharma Productions   500.0    950.0  Millions      INR    Hindi

# %%
df.shape
# Out:
# (37, 10)

# %%
df["imdb_rating"]
# Out:
# 0     8.3
# 1     7.0
# 2     6.8
# 3     7.9
# 4     6.8
# 5     9.3
# 6     8.6
# 7     8.0
# 8     8.5
# 9     7.9
# 10    8.6
# 11    7.8
# 12    9.2
# 13    9.0
# 14    9.0
# 15    8.2
# 16    8.5
# 17    8.4
# 18    8.4
# 19    6.9
# 20    7.8
# 21    8.0
# 22    8.4
# 23    7.4
# 24    7.2
# 25    8.3
# 26    8.1
# 27    8.1
# 28    NaN
# 29    8.3
# 30    8.1
# 31    1.9
# 32    8.4
# 33    8.4
# 34    7.6
# 35    8.0
# 36    8.0
# Name: imdb_rating, dtype: float64

# %%
df.imdb_rating.min(), df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (np.float64(1.9), np.float64(9.3), np.float64(7.919444444444445))

# %%
df_h = df[df.industry == 'Hollywood']
df_b = df[df.industry == 'Bollywood']

# %%
df_h.imdb_rating.min(),df.imdb_rating.max(), df.imdb_rating.mean()
# Out:
# (np.float64(6.8), np.float64(9.3), np.float64(7.919444444444445))

# %%
df_b.imdb_rating.min(),df_b.imdb_rating.max(), df_b.imdb_rating.mean()
# Out:
# (np.float64(1.9), np.float64(8.4), np.float64(7.656250000000001))

# %%
df = pd.read_csv('movies.csv')
print(f'All Movie ratings: Min: {df.imdb_rating.min()}, Max: {df.imdb_rating.max()}, Average: {df.imdb_rating.mean()}')

df_h = df[df.industry == 'Hollywood']
df_b = df[df.industry == 'Bollywood']

print(f'Hollwood ratings: Min: {df_h.imdb_rating.min()}, Max: {df_h.imdb_rating.max()}, Average: {df_h.imdb_rating.mean()}')
# Out:
# All Movie ratings: Min: 1.9, Max: 9.3, Average: 7.919444444444445
# Hollwood ratings: Min: 6.8, Max: 9.3, Average: 8.130000000000003
