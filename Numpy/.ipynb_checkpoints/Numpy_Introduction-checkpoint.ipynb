# %%
import numpy as np

# %%
arr = np.array([1,2,3])
arr
# Out:
# array([1, 2, 3])

# %%
python_list = list(range(100))
python_list[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
import sys

sys.getsizeof(python_list[0])*len(python_list)
# Out:
# 2800

# %%
numpy_array = np.arange(100)
numpy_array[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
numpy_array.nbytes
# Out:
# 800

# %%
size = 100000

l1 = list(range(size))
l2 = list(range(size))

l1[:5]
l2[:5]
# Out:
# [0, 1, 2, 3, 4]

# %%
import time

start_time = time.time()
l3 = [x+y for x,y in zip(l1,l2)]
end_time = time.time()

print("Python list took: ",end_time-start_time)
# Out:
# Python list took:  0.019503116607666016

# %%
n1 = np.arange(size)
n2 = np.arange(size)
n1[:5]
# Out:
# array([0, 1, 2, 3, 4])

# %%
start_time = time.time()
n3 = n1 + n2
end_time = time.time()

print("Numpy array took: ",end_time-start_time)
n3[:5]
# Out:
# Numpy array took:  0.0
# array([0, 2, 4, 6, 8])
